# %%
import matplotlib.pyplot as plt

# %%
import pandas as pd

df=pd.read_csv("summer.csv")

# %%
df
# Out:
#        Year    City      Sport           Discipline  \
# 0      1896  Athens   Aquatics             Swimming
# 1      1896  Athens   Aquatics             Swimming
# 2      1896  Athens   Aquatics             Swimming
# 3      1896  Athens   Aquatics             Swimming
# 4      1896  Athens   Aquatics             Swimming
# ...     ...     ...        ...                  ...
# 31160  2012  London  Wrestling  Wrestling Freestyle
# 31161  2012  London  Wrestling  Wrestling Freestyle
# 31162  2012  London  Wrestling  Wrestling Freestyle
# 31163  2012  London  Wrestling  Wrestling Freestyle
# 31164  2012  London  Wrestling  Wrestling Freestyle
#
#                          Athlete Country Gender                       Event  \
# 0                  HAJOS, Alfred     HUN    Men              100M Freestyle
# 1               HERSCHMANN, Otto     AUT    Men              100M Freestyle
# 2              DRIVAS, Dimitrios     GRE    Men  100M Freestyle For Sailors
# ...

# %%
#line graph:
#How many medals were won in each Olympic year?
#How many athletes participated each Olympic year?


m=df.groupby("Year")["Medal"].count()
print(m)

plt.plot(m.index,m.values)
# Out:
# Year
# 1896     151
# 1900     512
# 1904     470
# 1908     804
# 1912     885
# 1920    1298
# 1924     884
# 1928     710
# 1932     615
# 1936     875
# 1948     814
# 1952     889
# 1956     885
# 1960     882
# 1964    1010
# 1968    1031
# 1972    1185
# 1976    1305
# 1980    1387
# 1984    1459
# 1988    1546
# 1992    1705
# 1996    1859
# 2000    2015
# 2004    1998
# 2008    2042
# 2012    1949
# Name: Medal, dtype: int64

# %%
athlets=df.groupby("Year")["Athlete"].count()

plt.plot(m.index,m.values)

# %%
#Bar graph:
#Top 10 athletes with the most medals
#Top 10 teams with the highest medals
#Top 10 Olympic events by medal count

# %%
a=df.groupby("Medal")["Athlete"].count().head(10)
plt.bar(a.index,a.values)

plt.show()

# %%
#Pie Chart

#What percentage of medals are Gold, Silver, and Bronze?
#What percentage of athletes are Male and Female?
#What percentage of medals belong to the top 5 countries?

# %%
#Scatter plot:

#Relationship between Age and Height
